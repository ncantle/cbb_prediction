# %%
import urllib3
import pandas as pd
import string
from datetime import datetime
from bs4 import BeautifulSoup

pd.set_option('display.max_columns', None)

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
def get_season_schools(year):
    http = urllib3.PoolManager()
    URL = f'https://www.sports-reference.com/cbb/seasons/men/{year}-school-stats.html'
    r = http.request('GET', URL)
    soup = BeautifulSoup(r.data, 'html.parser')

    filename = 'data_file_' + datetime.today().strftime('%Y_%m_%d') + ".txt"
    with open(filename, 'w') as f:
        header = ','.join([item.get_text() for item in soup.select("table[id = 'basic_school_stats'] > thead > tr > th")][12:])
        print(header, file=f)
        for item in soup.select("table[id='basic_school_stats'] > tbody > tr"):
            row_data = ','.join( [ item.get_text() for item in item.select("td") ] )
            print(row_data, file=f)

    df = pd.read_csv(filename)
    cols = df.columns
    df.drop(columns = 'PF', inplace = True)
    df.columns = cols[1:]
    
    df.drop(columns = ['\xa0','\xa0.1','\xa0.2','\xa0.3','\xa0.4'], inplace = True)
    
    column_names = {
        'School':'school',
        'G':'games',
        'W':'wins',
        'L':'losses',
        'W-L%':'win_loss_percent',
        'SRS':'simple_rating_system',
        'SOS':'strength_of_schedule',
        'W.1':'conference_wins',
        'L.1':'conference_losses',
        'W.2':'home_wins',
        'L.2':'home_losses',
        'W.3':'away_wins',
        'L.3':'away_losses',
        'Tm.':'points_for',
        'Opp.':'points_against',
        'MP':'minutes_played',
        'FG':'field_goals',
        'FGA':'field_goals_attempted',
        'FG%':'field_goal_percent',
        '3P':'three_pointers',
        '3PA':'three_pointers_attempted',
        '3P%':'three_pointer_percentage',
        'FT':'free_throws',
        'FTA':'free_throws_attempted',
        'FT%':'free_throw_percentage',
        'ORB':'offensive_rebounds',
        'TRB':'total_rebounds',
        'AST':'assists',
        'STL':'steals',
        'BLK':'blocks',
        'TOV':'turnovers',
        'PF':'personal_fouls'
        }

    df.columns = df.columns.map(column_names)
    
    schools = df['school'].unique()
    school_dict = {}
    for school in schools:
        school_dict[school] = school.lower().translate(str.maketrans('','',string.punctuation)).replace(' ','-')
    
    return df, school_dict

# %%
df, school_dict = get_season_schools(2025)
df
# Out:
#                 school  games  wins  losses  win_loss_percent  \
# 0    Abilene Christian     21     9      12             0.429
# 1            Air Force     21     3      18             0.143
# 2                Akron     20    15       5             0.750
# 3              Alabama     21    18       3             0.857
# 4          Alabama A&M     20     7      13             0.350
# ..                 ...    ...   ...     ...               ...
# 359       Wright State     22    11      11             0.500
# 360            Wyoming     21    11      10             0.524
# 361             Xavier     22    13       9             0.591
# 362               Yale     17    11       6             0.647
# 363   Youngstown State     22    13       9             0.591
#
#      simple_rating_system  strength_of_schedule  conference_wins  \
# 0                   -7.41                 -0.58                1
# 1                   -6.69                  1.45                0
# 2                    3.76                 -3.80                8
# 3                   25.00                 13.52                7
# 4                  -19.11                 -7.52                3
# ..                    ...                   ...              ...
# 359                 -2.53                 -2.68                5
# 360                  0.02                  2.92                4
# 361                 14.18                  7.41                5
# 362                  7.47                 -2.91                4
# 363                 -5.09                 -5.29                7
#
#      conference_losses  home_wins  home_losses  away_wins  away_losses  \
# 0                    5          6            4          2            8
# 1                   10          2            9          0            9
# 2                    0         10            0          4            3
# 3                    1          9            1          6            1
# 4                    4          7            6          0            7
# ..                 ...        ...          ...        ...          ...
# 359                  6          7            3          3            6
# 360                  6          7            3          3            5
# 361                  6         10            2          2            6
# 362                  0          7            0          2            5
# 363                  4          6            3          6            5
#
#      points_for  points_against  minutes_played  field_goals  \
# 0          1473            1486             845          533
# 1          1330            1501             845          455
# 2          1680            1460             805          606
# 3          1895            1654             845          639
# 4          1540            1614             820          531
# ..          ...             ...             ...          ...
# 359        1694            1626             890          630
# 360        1453            1488             845          519
# 361        1693            1544             890          569
# 362        1400            1180             680          504
# 363        1660            1539             890          570
#
#      field_goals_attempted  field_goal_percent  three_pointers  \
# 0                     1200               0.444             100
# 1                     1043               0.436             169
# 2                     1328               0.456             230
# 3                     1348               0.474             213
# 4                     1298               0.409             167
# ..                     ...                 ...             ...
# 359                   1301               0.484             183
# 360                   1166               0.445             168
# 361                   1257               0.453             180
# 362                   1051               0.480             133
# 363                   1333               0.428             188
#
#      three_pointers_attempted  three_pointer_percentage  free_throws  \
# 0                         332                     0.301          307
# 1                         497                     0.340          251
# 2                         636                     0.362          238
# 3                         641                     0.332          404
# 4                         523                     0.319          311
# ..                        ...                       ...          ...
# 359                       485                     0.377          251
# 360                       467                     0.360          247
# 361                       470                     0.383          375
# 362                       346                     0.384          259
# 363                       608                     0.309          332
#
#      free_throws_attempted  free_throw_percentage  offensive_rebounds  \
# 0                      441                  0.696                 235
# 1                      400                  0.628                 157
# 2                      314                  0.758                 259
# 3                      574                  0.704                 298
# 4                      467                  0.666                 310
# ..                     ...                    ...                 ...
# 359                    352                  0.713                 206
# 360                    368                  0.671                 225
# 361                    482                  0.778                 195
# 362                    349                  0.742                 213
# 363                    464                  0.716                 250
#
#      total_rebounds  assists  steals  blocks  turnovers  personal_fouls
# 0               714      278     210      61        317             427
# 1               625      280     123      64        279             363
# 2               823      367     158      74        253             367
# 3               933      358     134     105        271             387
# 4               784      295     178      88        339             436
# ..              ...      ...     ...     ...        ...             ...
# 359             783      327     129      65        251             376
# 360             743      250      89      59        275             387
# 361             753      362     165      66        250             359
# 362             690      302     101      61        186             298
# 363             822      303     150     122        274             408
#
# [364 rows x 32 columns]

# %%
def players_per_game(year):
    http = urllib3.PoolManager()
    URL = f'https://www.sports-reference.com/cbb/schools/abilene-christian/men/{year}.html'
    r = http.request('GET', URL)
    soup = BeautifulSoup(r.data, 'html.parser')

    filename = 'players_per_game' + datetime.today().strftime('%Y_%m_%d') + ".txt"
    with open(filename, 'w') as f:
        header = ','.join([item.get_text() for item in soup.select("table[id = 'players_per_game'] > thead > tr > th")])
        print(header, file=f)
        for item in soup.select("table[id='players_per_game'] > tbody > tr"):
            row_data = ','.join( [ item.get_text() for item in item.select("td") ] )
            print(row_data, file=f)

    df = pd.read_csv(filename)
    cols = df.columns
    df.drop(columns = 'Awards', inplace = True)
    df.columns = cols[1:]
    
    return df

# %%
player_df = players_per_game(2025)

# %%
opp_df = df.copy()
opp_df.columns = ['opp_' + item for item in df.columns]

pd.concat([df[df['school'] == 'Abilene Christian'].reset_index(drop = True), opp_df[opp_df['opp_school'] == 'Akron'].reset_index(drop = True)], axis = 1)
# Out:
#               school  games  wins  losses  win_loss_percent  \
# 0  Abilene Christian     21     9      12             0.429
#
#    simple_rating_system  strength_of_schedule  conference_wins  \
# 0                 -7.34                 -0.51                1
#
#    conference_losses  home_wins  home_losses  away_wins  away_losses  \
# 0                  5          6            4          2            8
#
#    points_for  points_against  minutes_played  field_goals  \
# 0        1473            1486             845          533
#
#    field_goals_attempted  field_goal_percent  three_pointers  \
# 0                   1200               0.444             100
#
#    three_pointers_attempted  three_pointer_percentage  free_throws  \
# 0                       332                     0.301          307
#
#    free_throws_attempted  free_throw_percentage  offensive_rebounds  \
# 0                    441                  0.696                 235
#
#    total_rebounds  assists  steals  blocks  turnovers  personal_fouls  \
# 0             714      278     210      61        317             427
#
#   opp_school  opp_games  opp_wins  opp_losses  opp_win_loss_percent  \
# 0      Akron         20        15           5                  0.75
#
#    opp_simple_rating_system  opp_strength_of_schedule  opp_conference_wins  \
# 0                       3.8                     -3.76                    8
#
#    opp_conference_losses  opp_home_wins  opp_home_losses  opp_away_wins  \
# 0                      0             10                0              4
#
#    opp_away_losses  opp_points_for  opp_points_against  opp_minutes_played  \
# 0                3            1680                1460                 805
#
#    opp_field_goals  opp_field_goals_attempted  opp_field_goal_percent  \
# 0              606                       1328                   0.456
#
#    opp_three_pointers  opp_three_pointers_attempted  \
# 0                 230                           636
#
#    opp_three_pointer_percentage  opp_free_throws  opp_free_throws_attempted  \
# 0                         0.362              238                        314
#
#    opp_free_throw_percentage  opp_offensive_rebounds  opp_total_rebounds  \
# 0                      0.758                     259                 823
#
#    opp_assists  opp_steals  opp_blocks  opp_turnovers  opp_personal_fouls
# 0          367         158          74            253                 367
